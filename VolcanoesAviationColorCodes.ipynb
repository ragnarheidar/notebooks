# %%
import requests
import json
from datetime import datetime
import pandas as pd
import geopandas
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       3 from datetime import datetime
#       4 import pandas as pd
# ----> 5 import geopandas
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/geopandas/__init__.py:1, in <module>
# ----> 1 from geopandas.geoseries import GeoSeries  # noqa
#       2 from geopandas.geodataframe import GeoDataFrame  # noqa
#       3 from geopandas.array import _points_from_xy as points_from_xy  # noqa
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/geopandas/geoseries.py:12, in <module>
#       9 from pandas.core.internals import SingleBlockManager
#      11 import pyproj
# ---> 12 from shapely.geometry.base import BaseGeometry
#      13 from shapely.ops import transform
#      15 from geopandas.base import GeoPandasBase, _delegate_property
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/shapely/geometry/__init__.py:4, in <module>
#       1 """Geometry classes and factories
#       2 """
# ----> 4 from .base import CAP_STYLE, JOIN_STYLE
#       5 from .geo import box, shape, asShape, mapping
#       6 from .point import Point, asPoint
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/shapely/geometry/base.py:17, in <module>
#      14 from warnings import warn
#      16 from shapely.affinity import affine_transform
# ---> 17 from shapely.coords import CoordinateSequence
#      18 from shapely.errors import WKBReadingError, WKTReadingError
#      19 from shapely.ftools import wraps
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/shapely/coords.py:8, in <module>
#       5 from array import array
#       6 from ctypes import byref, c_double, c_uint
# ----> 8 from shapely.geos import lgeos
#       9 from shapely.topology import Validating
#      11 if sys.version_info[0] < 3:
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/shapely/geos.py:113, in <module>
#     103         alt_paths = [
#     104             # anaconda
#     105             os.path.join(sys.prefix, "lib", "libgeos_c.dylib"),
#    (...)
#     109             '/opt/local/lib/libgeos_c.dylib',
#     110         ]
#     111     _lgeos = load_dll('geos_c', fallbacks=alt_paths)
# --> 113 free = load_dll('c').free
#     114 free.argtypes = [c_void_p]
#     115 free.restype = None
#
# File ~/.conda/envs/geo/lib/python3.8/site-packages/shapely/geos.py:54, in load_dll(libname, fallbacks, mode)
#      51     return dll
#      52 else:
#      53     # No shared library was loaded. Raise OSError.
# ---> 54     raise OSError(
#      55         "Could not find lib {0} or load any of its variants {1}.".format(
#      56             libname, fallbacks or []))
#
# OSError: Could not find lib c or load any of its variants [].

# %%
# sting to get volcanoes and their colors
# https://api.vedur.is/epos/v1/volcanoes/products/aviation_color_codes?
# start_time=2022-09-16T00%3A00%3A00Z&end_time=2022-09-16T00%3A00%3A00Z&volcano=Fagradalsfjall

# build request sting
base_url = 'https://api.vedur.is/epos/v1/volcanoes/products/aviation_color_codes?'
get_datetime = datetime.now()
timestamp = get_datetime.strftime('%Y-%m-%dT%TZ') # this will give YYYY-MM-DDTHH:MM:SSZ
start = 'start_time=' + str(timestamp)
end = 'end_time' + str(timestamp)
# volcano = 'volcano=Fagradalsfjall'
string = base_url + start + '&' + end # + '&' + volcano
print(string)

# %%
r = requests.get(string)
r.json()
# Out:
# {'data': [{'latitude': 65.05,
#    'longitude': -16.783,
#    'publication_date': '2021-09-09T16:33:34.079986',
#    'source_of_information': 'IMO',
#    'status': 'yellow',
#    'volcano_id': '373060',
#    'volcano_name': 'Askja',
#    'volcano_name_si': 'Askja'},
#   {'latitude': 64.633,
#    'longitude': -17.517,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373030',
#    'volcano_name': 'Bárðarbunga',
#    'volcano_name_si': 'Bardarbunga'},
#   {'latitude': 63.95,
#    'longitude': -21.75,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371040',
#    'volcano_name': 'Brennisteinsfjöll',
#    'volcano_name_si': 'Brennisteinsfjoll'},
#   {'latitude': 64.283,
#    'longitude': -16.583,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '374020',
#    'volcano_name': 'Esjufjöll',
#    'volcano_name_si': 'Esjufjoll'},
#   {'latitude': 63.628,
#    'longitude': -19.625,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372020',
#    'volcano_name': 'Eyjafjallajökull',
#    'volcano_name_si': 'Eyjafjallajokull'},
#   {'latitude': 65.433,
#    'longitude': -16.667,
#    'publication_date': '2020-10-28T14:38:01.123294',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373070',
#    'volcano_name': 'Fremrinámar',
#    'volcano_name_si': 'Fremrinamar'},
#   {'latitude': 64.05,
#    'longitude': -20.883,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371060',
#    'volcano_name': 'Grímsnes',
#    'volcano_name_si': 'Grimsnes'},
#   {'latitude': 64.417,
#    'longitude': -17.333,
#    'publication_date': '2022-08-09T17:24:03.913471',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373010',
#    'volcano_name': 'Grímsvötn',
#    'volcano_name_si': 'Grimsvotn'},
#   {'latitude': 65.583,
#    'longitude': -16.817,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373082',
#    'volcano_name': 'Heiðarsporðar',
#    'volcano_name_si': 'Heidarspordar '},
#   {'latitude': 63.992,
#    'longitude': -19.667,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372070',
#    'volcano_name': 'Hekla',
#    'volcano_name_si': 'Hekla'},
#   {'latitude': 64.083,
#    'longitude': -21.3,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371050',
#    'volcano_name': 'Hengill',
#    'volcano_name_si': 'Hengill'},
#   {'latitude': 64.8,
#    'longitude': -18.9,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371090',
#    'volcano_name': 'Hofsjökull',
#    'volcano_name_si': 'Hofsjokull'},
#   {'latitude': 64.067,
#    'longitude': -21.2,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371051',
#    'volcano_name': 'Hrómundartindur',
#    'volcano_name_si': 'Hromundartindur'},
#   {'latitude': 63.633,
#    'longitude': -19.117,
#    'publication_date': '2017-07-31T15:02:14.443359',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372030',
#    'volcano_name': 'Katla',
#    'volcano_name_si': 'Katla'},
#   {'latitude': 65.717,
#    'longitude': -16.783,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373080',
#    'volcano_name': 'Krafla',
#    'volcano_name_si': 'Krafla'},
#   {'latitude': 63.917,
#    'longitude': -22.067,
#    'publication_date': '2022-09-15T15:29:52.10819',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371030',
#    'volcano_name': 'Krýsuvík',
#    'volcano_name_si': 'Krysuvik'},
#   {'latitude': 64.65,
#    'longitude': -16.667,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373050',
#    'volcano_name': 'Kverkfjöll',
#    'volcano_name_si': 'Kverkfjoll'},
#   {'latitude': 64.917,
#    'longitude': -22.633,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '370030',
#    'volcano_name': 'Ljósufjöll',
#    'volcano_name_si': 'Ljosufjoll'},
#   {'latitude': 64.867,
#    'longitude': -23.25,
#    'publication_date': '2020-11-12T14:36:08.129673',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '370020',
#    'volcano_name': 'Helgrindur',
#    'volcano_name_si': 'Helgrindur'},
#   {'latitude': 64.85,
#    'longitude': -19.783,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371080',
#    'volcano_name': 'Langjökull',
#    'volcano_name_si': 'Langjokull'},
#   {'latitude': 64.6,
#    'longitude': -20.633,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371070',
#    'volcano_name': 'Prestahnúkur',
#    'volcano_name_si': 'Prestahnukur'},
#   {'latitude': 63.817,
#    'longitude': -22.717,
#    'publication_date': '2022-06-02T11:49:38.51324',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371020',
#    'volcano_name': 'Reykjanes',
#    'volcano_name_si': 'Reykjanes'},
#   {'latitude': 64.8,
#    'longitude': -15.567,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '374801',
#    'volcano_name': 'Snæfell',
#    'volcano_name_si': 'Snaefell'},
#   {'latitude': 64.8,
#    'longitude': -23.783,
#    'publication_date': '2020-11-12T14:33:34.946495',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '370010',
#    'volcano_name': 'Snæfellsjökull',
#    'volcano_name_si': 'Snaefellsjokull'},
#   {'latitude': 63.783,
#    'longitude': -19.567,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372040',
#    'volcano_name': 'Tindfjallajökull',
#    'volcano_name_si': 'Tindfjallajokull'},
#   {'latitude': 63.933,
#    'longitude': -19.1,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372050',
#    'volcano_name': 'Torfajökull',
#    'volcano_name_si': 'Torfajokull'},
#   {'latitude': 64.75,
#    'longitude': -17.917,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373040',
#    'volcano_name': 'Tungnafellsjökull',
#    'volcano_name_si': 'Tungnafellsjokull'},
#   {'latitude': 63.417,
#    'longitude': -20.35,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '372010',
#    'volcano_name': 'Vestmannaeyjar',
#    'volcano_name_si': 'Vestmannaeyjar'},
#   {'latitude': 65.883,
#    'longitude': -16.967,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373090',
#    'volcano_name': 'Þeistareykir',
#    'volcano_name_si': 'Theistareykir'},
#   {'latitude': 64.267,
#    'longitude': -17.617,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '373012',
#    'volcano_name': 'Þórðarhyrna',
#    'volcano_name_si': 'Grimsvotn'},
#   {'latitude': 64,
#    'longitude': -16.65,
#    'publication_date': '2018-05-04T11:24:22.418449',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '374010',
#    'volcano_name': 'Öræfajökull',
#    'volcano_name_si': 'Oraefajokull'},
#   {'latitude': 63.733,
#    'longitude': -23,
#    'publication_date': '2015-03-01T00:00:00',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371022',
#    'volcano_name': 'Eldey',
#    'volcano_name_si': 'Reykjanes'},
#   {'latitude': 63.895,
#    'longitude': -22.258,
#    'publication_date': '2022-09-15T15:27:36.663271',
#    'source_of_information': 'IMO',
#    'status': 'green',
#    'volcano_id': '371032',
#    'volcano_name': 'Fagradalsfjall',
#    'volcano_name_si': 'Fagradalsfjall'}],
#  'success': True}

# %%
# r.encoding = 'ISO-8859-1'
data = r.json()['data'] # add data to get nested list
with open('data.json', 'w') as f:
    json.dump(data, f)
f.close()

# %%
df = pd.read_json('data.json')

# %%
# Out:
#     latitude  longitude            publication_date source_of_information  \
# 0     65.050    -16.783  2021-09-09T16:33:34.079986                   IMO
# 1     64.633    -17.517         2015-03-01T00:00:00                   IMO
# 2     63.950    -21.750         2015-03-01T00:00:00                   IMO
# 3     64.283    -16.583         2015-03-01T00:00:00                   IMO
# 4     63.628    -19.625         2015-03-01T00:00:00                   IMO
# 5     65.433    -16.667  2020-10-28T14:38:01.123294                   IMO
# 6     64.050    -20.883         2015-03-01T00:00:00                   IMO
# 7     64.417    -17.333  2022-08-09T17:24:03.913471                   IMO
# 8     65.583    -16.817         2015-03-01T00:00:00                   IMO
# 9     63.992    -19.667         2015-03-01T00:00:00                   IMO
# 10    64.083    -21.300         2015-03-01T00:00:00                   IMO
# 11    64.800    -18.900         2015-03-01T00:00:00                   IMO
# 12    64.067    -21.200         2015-03-01T00:00:00                   IMO
# 13    63.633    -19.117  2017-07-31T15:02:14.443359                   IMO
# 14    65.717    -16.783         2015-03-01T00:00:00                   IMO
# 15    63.917    -22.067   2022-09-15T15:29:52.10819                   IMO
# 16    64.650    -16.667         2015-03-01T00:00:00                   IMO
# 17    64.917    -22.633         2015-03-01T00:00:00                   IMO
# 18    64.867    -23.250  2020-11-12T14:36:08.129673                   IMO
# 19    64.850    -19.783         2015-03-01T00:00:00                   IMO
# 20    64.600    -20.633         2015-03-01T00:00:00                   IMO
# 21    63.817    -22.717   2022-06-02T11:49:38.51324                   IMO
# 22    64.800    -15.567         2015-03-01T00:00:00                   IMO
# 23    64.800    -23.783  2020-11-12T14:33:34.946495                   IMO
# 24    63.783    -19.567         2015-03-01T00:00:00                   IMO
# 25    63.933    -19.100         2015-03-01T00:00:00                   IMO
# 26    64.750    -17.917         2015-03-01T00:00:00                   IMO
# 27    63.417    -20.350         2015-03-01T00:00:00                   IMO
# 28    65.883    -16.967         2015-03-01T00:00:00                   IMO
# 29    64.267    -17.617         2015-03-01T00:00:00                   IMO
# 30    64.000    -16.650  2018-05-04T11:24:22.418449                   IMO
# 31    63.733    -23.000         2015-03-01T00:00:00                   IMO
# 32    63.895    -22.258  2022-09-15T15:27:36.663271                   IMO
#
#     status  volcano_id       volcano_name    volcano_name_si
# 0   yellow      373060              Askja              Askja
# 1    green      373030        Bárðarbunga        Bardarbunga
# 2    green      371040  Brennisteinsfjöll  Brennisteinsfjoll
# 3    green      374020          Esjufjöll          Esjufjoll
# 4    green      372020   Eyjafjallajökull   Eyjafjallajokull
# 5    green      373070        Fremrinámar        Fremrinamar
# 6    green      371060           Grímsnes           Grimsnes
# 7    green      373010          Grímsvötn          Grimsvotn
# 8    green      373082      Heiðarsporðar     Heidarspordar
# 9    green      372070              Hekla              Hekla
# 10   green      371050            Hengill            Hengill
# 11   green      371090         Hofsjökull         Hofsjokull
# 12   green      371051    Hrómundartindur    Hromundartindur
# 13   green      372030              Katla              Katla
# 14   green      373080             Krafla             Krafla
# 15   green      371030           Krýsuvík           Krysuvik
# 16   green      373050         Kverkfjöll         Kverkfjoll
# 17   green      370030         Ljósufjöll         Ljosufjoll
# 18   green      370020         Helgrindur         Helgrindur
# 19   green      371080         Langjökull         Langjokull
# 20   green      371070       Prestahnúkur       Prestahnukur
# 21   green      371020          Reykjanes          Reykjanes
# 22   green      374801            Snæfell           Snaefell
# 23   green      370010     Snæfellsjökull    Snaefellsjokull
# 24   green      372040   Tindfjallajökull   Tindfjallajokull
# 25   green      372050        Torfajökull        Torfajokull
# 26   green      373040  Tungnafellsjökull  Tungnafellsjokull
# 27   green      372010     Vestmannaeyjar     Vestmannaeyjar
# 28   green      373090       Þeistareykir      Theistareykir
# 29   green      373012        Þórðarhyrna          Grimsvotn
# 30   green      374010        Öræfajökull       Oraefajokull
# 31   green      371022              Eldey          Reykjanes
# 32   green      371032     Fagradalsfjall     Fagradalsfjall
